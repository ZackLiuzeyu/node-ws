# %% [markdown]
# <a href="https://colab.research.google.com/github/ZackLiuzeyu/node-ws/blob/main/Zinc_download.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prepare for downloading
#
# - The download script is generated on 10 Feb 2023

# %%
# !git clone https://github.com/quantaosun/Zinc-Million.git
# !cp /content/Zinc-Million/ZINC-downloader-3D-sdf.gz.wget .
# !cat ZINC-downloader-3D-sdf.gz.wget > download.sh
# Out:
# Cloning into 'Zinc-Million'...
# remote: Enumerating objects: 73, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 73 (delta 37), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (73/73), 2.52 MiB | 9.47 MiB/s, done.
# Resolving deltas: 100% (37/37), done.

# %% [markdown]
# # Download

# %%
# !sh download.sh
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# HTTP request sent, awaiting response... 200 OK
# Length: 483248 (472K) [application/x-gzip]
# Saving to: ‘EE/ABMP/EEABMP.xaa.sdf.gz’
#
# EE/ABMP/EEABMP.xaa. 100%[===================>] 471.92K   442KB/s    in 1.1s
#
# 2025-12-18 06:31:16 (442 KB/s) - ‘EE/ABMP/EEABMP.xaa.sdf.gz’ saved [483248/483248]
#
# mkdir: created directory 'EE/ABRL'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:16--  https://files.docking.org/3D/EE/ABRL/EEABRL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58177 (57K) [application/x-gzip]
# Saving to: ‘EE/ABRL/EEABRL.xaa.sdf.gz’
#
# EE/ABRL/EEABRL.xaa. 100%[===================>]  56.81K   322KB/s    in 0.2s
#
# 2025-12-18 06:31:16 (322 KB/s) - ‘EE/ABRL/EEABRL.xaa.sdf.gz’ saved [58177/58177]
#
# mkdir: created directory 'EE/ABRM'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:16--  https://files.docking.org/3D/EE/ABRM/EEABRM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1647670 (1.6M) [application/x-gzip]
# Saving to: ‘EE/ABRM/EEABRM.xaa.sdf.gz’
#
# EE/ABRM/EEABRM.xaa. 100%[===================>]   1.57M   557KB/s    in 2.9s
#
# 2025-12-18 06:31:19 (557 KB/s) - ‘EE/ABRM/EEABRM.xaa.sdf.gz’ saved [1647670/1647670]
#
# mkdir: created directory 'EE/ABRO'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:19--  https://files.docking.org/3D/EE/ABRO/EEABRO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6747322 (6.4M) [application/x-gzip]
# Saving to: ‘EE/ABRO/EEABRO.xaa.sdf.gz’
#
# EE/ABRO/EEABRO.xaa. 100%[===================>]   6.43M  1.74MB/s    in 4.0s
#
# 2025-12-18 06:31:24 (1.62 MB/s) - ‘EE/ABRO/EEABRO.xaa.sdf.gz’ saved [6747322/6747322]
#
# mkdir: created directory 'EE/ABRP'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:24--  https://files.docking.org/3D/EE/ABRP/EEABRP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 246654 (241K) [application/x-gzip]
# Saving to: ‘EE/ABRP/EEABRP.xaa.sdf.gz’
#
# EE/ABRP/EEABRP.xaa. 100%[===================>] 240.87K   367KB/s    in 0.7s
#
# 2025-12-18 06:31:24 (367 KB/s) - ‘EE/ABRP/EEABRP.xaa.sdf.gz’ saved [246654/246654]
#
# mkdir: created directory 'EE/BAML'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:24--  https://files.docking.org/3D/EE/BAML/EEBAML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4633 (4.5K) [application/x-gzip]
# Saving to: ‘EE/BAML/EEBAML.xaa.sdf.gz’
#
# EE/BAML/EEBAML.xaa. 100%[===================>]   4.52K  --.-KB/s    in 0s
#
# 2025-12-18 06:31:25 (2.02 GB/s) - ‘EE/BAML/EEBAML.xaa.sdf.gz’ saved [4633/4633]
#
# mkdir: created directory 'EE/BAMM'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:25--  https://files.docking.org/3D/EE/BAMM/EEBAMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33319 (33K) [application/x-gzip]
# Saving to: ‘EE/BAMM/EEBAMM.xaa.sdf.gz’
#
# EE/BAMM/EEBAMM.xaa. 100%[===================>]  32.54K  --.-KB/s    in 0.1s
#
# 2025-12-18 06:31:25 (336 KB/s) - ‘EE/BAMM/EEBAMM.xaa.sdf.gz’ saved [33319/33319]
#
# mkdir: created directory 'EE/BAMO'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:25--  https://files.docking.org/3D/EE/BAMO/EEBAMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 77054 (75K) [application/x-gzip]
# Saving to: ‘EE/BAMO/EEBAMO.xaa.sdf.gz’
#
# EE/BAMO/EEBAMO.xaa. 100%[===================>]  75.25K   309KB/s    in 0.2s
#
# 2025-12-18 06:31:26 (309 KB/s) - ‘EE/BAMO/EEBAMO.xaa.sdf.gz’ saved [77054/77054]
#
# mkdir: created directory 'EE/BAMP'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:26--  https://files.docking.org/3D/EE/BAMP/EEBAMP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1828 (1.8K) [application/x-gzip]
# Saving to: ‘EE/BAMP/EEBAMP.xaa.sdf.gz’
#
# EE/BAMP/EEBAMP.xaa. 100%[===================>]   1.79K  --.-KB/s    in 0s
#
# 2025-12-18 06:31:26 (934 MB/s) - ‘EE/BAMP/EEBAMP.xaa.sdf.gz’ saved [1828/1828]
#
# mkdir: created directory 'EE/BARL'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:26--  https://files.docking.org/3D/EE/BARL/EEBARL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16049 (16K) [application/x-gzip]
# Saving to: ‘EE/BARL/EEBARL.xaa.sdf.gz’
#
# EE/BARL/EEBARL.xaa. 100%[===================>]  15.67K  --.-KB/s    in 0.05s
#
# 2025-12-18 06:31:26 (325 KB/s) - ‘EE/BARL/EEBARL.xaa.sdf.gz’ saved [16049/16049]
#
# mkdir: created directory 'EE/BARM'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:26--  https://files.docking.org/3D/EE/BARM/EEBARM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 146343 (143K) [application/x-gzip]
# Saving to: ‘EE/BARM/EEBARM.xaa.sdf.gz’
#
# EE/BARM/EEBARM.xaa. 100%[===================>] 142.91K   355KB/s    in 0.4s
#
# 2025-12-18 06:31:27 (355 KB/s) - ‘EE/BARM/EEBARM.xaa.sdf.gz’ saved [146343/146343]
#
# mkdir: created directory 'EE/BARO'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:27--  https://files.docking.org/3D/EE/BARO/EEBARO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 104427 (102K) [application/x-gzip]
# Saving to: ‘EE/BARO/EEBARO.xaa.sdf.gz’
#
# EE/BARO/EEBARO.xaa. 100%[===================>] 101.98K   341KB/s    in 0.3s
#
# 2025-12-18 06:31:27 (341 KB/s) - ‘EE/BARO/EEBARO.xaa.sdf.gz’ saved [104427/104427]
#
# mkdir: created directory 'EE/BARP'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:27--  https://files.docking.org/3D/EE/BARP/EEBARP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3505 (3.4K) [application/x-gzip]
# Saving to: ‘EE/BARP/EEBARP.xaa.sdf.gz’
#
# EE/BARP/EEBARP.xaa. 100%[===================>]   3.42K  --.-KB/s    in 0s
#
# 2025-12-18 06:31:28 (1.17 GB/s) - ‘EE/BARP/EEBARP.xaa.sdf.gz’ saved [3505/3505]
#
# mkdir: created directory 'EE/BBML'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:28--  https://files.docking.org/3D/EE/BBML/EEBBML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3279 (3.2K) [application/x-gzip]
# Saving to: ‘EE/BBML/EEBBML.xaa.sdf.gz’
#
# EE/BBML/EEBBML.xaa. 100%[===================>]   3.20K  --.-KB/s    in 0s
#
# 2025-12-18 06:31:28 (955 MB/s) - ‘EE/BBML/EEBBML.xaa.sdf.gz’ saved [3279/3279]
#
# mkdir: created directory 'EE/BBMM'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:28--  https://files.docking.org/3D/EE/BBMM/EEBBMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16924 (17K) [application/x-gzip]
# Saving to: ‘EE/BBMM/EEBBMM.xaa.sdf.gz’
#
# EE/BBMM/EEBBMM.xaa. 100%[===================>]  16.53K  --.-KB/s    in 0.05s
#
# 2025-12-18 06:31:28 (339 KB/s) - ‘EE/BBMM/EEBBMM.xaa.sdf.gz’ saved [16924/16924]
#
# mkdir: created directory 'EE/BBMO'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:28--  https://files.docking.org/3D/EE/BBMO/EEBBMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 74082 (72K) [application/x-gzip]
# Saving to: ‘EE/BBMO/EEBBMO.xaa.sdf.gz’
#
# EE/BBMO/EEBBMO.xaa. 100%[===================>]  72.35K   356KB/s    in 0.2s
#
# 2025-12-18 06:31:29 (356 KB/s) - ‘EE/BBMO/EEBBMO.xaa.sdf.gz’ saved [74082/74082]
#
# mkdir: created directory 'EE/BBRL'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:29--  https://files.docking.org/3D/EE/BBRL/EEBBRL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9420 (9.2K) [application/x-gzip]
# Saving to: ‘EE/BBRL/EEBBRL.xaa.sdf.gz’
#
# EE/BBRL/EEBBRL.xaa. 100%[===================>]   9.20K  --.-KB/s    in 0s
#
# 2025-12-18 06:31:29 (103 MB/s) - ‘EE/BBRL/EEBBRL.xaa.sdf.gz’ saved [9420/9420]
#
# mkdir: created directory 'EE/BBRM'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:29--  https://files.docking.org/3D/EE/BBRM/EEBBRM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 122709 (120K) [application/x-gzip]
# Saving to: ‘EE/BBRM/EEBBRM.xaa.sdf.gz’
#
# EE/BBRM/EEBBRM.xaa. 100%[===================>] 119.83K   353KB/s    in 0.3s
#
# 2025-12-18 06:31:29 (353 KB/s) - ‘EE/BBRM/EEBBRM.xaa.sdf.gz’ saved [122709/122709]
#
# mkdir: created directory 'EE/BBRO'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:29--  https://files.docking.org/3D/EE/BBRO/EEBBRO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 99857 (98K) [application/x-gzip]
# Saving to: ‘EE/BBRO/EEBBRO.xaa.sdf.gz’
#
# EE/BBRO/EEBBRO.xaa. 100%[===================>]  97.52K   325KB/s    in 0.3s
#
# 2025-12-18 06:31:30 (325 KB/s) - ‘EE/BBRO/EEBBRO.xaa.sdf.gz’ saved [99857/99857]
#
# mkdir: created directory 'EE/BBRP'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:30--  https://files.docking.org/3D/EE/BBRP/EEBBRP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3901 (3.8K) [application/x-gzip]
# Saving to: ‘EE/BBRP/EEBBRP.xaa.sdf.gz’
#
# EE/BBRP/EEBBRP.xaa. 100%[===================>]   3.81K  --.-KB/s    in 0s
#
# 2025-12-18 06:31:30 (1.39 GB/s) - ‘EE/BBRP/EEBBRP.xaa.sdf.gz’ saved [3901/3901]
#
# mkdir: created directory 'EE/CAML'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:30--  https://files.docking.org/3D/EE/CAML/EECAML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5786 (5.7K) [application/x-gzip]
# Saving to: ‘EE/CAML/EECAML.xaa.sdf.gz’
#
# EE/CAML/EECAML.xaa. 100%[===================>]   5.65K  --.-KB/s    in 0s
#
# 2025-12-18 06:31:30 (3.00 GB/s) - ‘EE/CAML/EECAML.xaa.sdf.gz’ saved [5786/5786]
#
# mkdir: created directory 'EE/CAMM'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:30--  https://files.docking.org/3D/EE/CAMM/EECAMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 78640 (77K) [application/x-gzip]
# Saving to: ‘EE/CAMM/EECAMM.xaa.sdf.gz’
#
# EE/CAMM/EECAMM.xaa. 100%[===================>]  76.80K   311KB/s    in 0.2s
#
# 2025-12-18 06:31:31 (311 KB/s) - ‘EE/CAMM/EECAMM.xaa.sdf.gz’ saved [78640/78640]
#
# mkdir: created directory 'EE/CAMO'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:31--  https://files.docking.org/3D/EE/CAMO/EECAMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 59816 (58K) [application/x-gzip]
# Saving to: ‘EE/CAMO/EECAMO.xaa.sdf.gz’
#
# EE/CAMO/EECAMO.xaa. 100%[===================>]  58.41K   365KB/s    in 0.2s
#
# 2025-12-18 06:31:31 (365 KB/s) - ‘EE/CAMO/EECAMO.xaa.sdf.gz’ saved [59816/59816]
#
# mkdir: created directory 'EE/CAMP'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:31--  https://files.docking.org/3D/EE/CAMP/EECAMP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5380 (5.3K) [application/x-gzip]
# Saving to: ‘EE/CAMP/EECAMP.xaa.sdf.gz’
#
# EE/CAMP/EECAMP.xaa. 100%[===================>]   5.25K  --.-KB/s    in 0s
#
# 2025-12-18 06:31:31 (2.21 GB/s) - ‘EE/CAMP/EECAMP.xaa.sdf.gz’ saved [5380/5380]
#
# mkdir: created directory 'EE/CARL'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:31--  https://files.docking.org/3D/EE/CARL/EECARL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15160 (15K) [application/x-gzip]
# Saving to: ‘EE/CARL/EECARL.xaa.sdf.gz’
#
# EE/CARL/EECARL.xaa. 100%[===================>]  14.80K  --.-KB/s    in 0.05s
#
# 2025-12-18 06:31:32 (300 KB/s) - ‘EE/CARL/EECARL.xaa.sdf.gz’ saved [15160/15160]
#
# mkdir: created directory 'EE/CARM'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:32--  https://files.docking.org/3D/EE/CARM/EECARM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 235948 (230K) [application/x-gzip]
# Saving to: ‘EE/CARM/EECARM.xaa.sdf.gz’
#
# EE/CARM/EECARM.xaa. 100%[===================>] 230.42K   393KB/s    in 0.6s
#
# 2025-12-18 06:31:33 (393 KB/s) - ‘EE/CARM/EECARM.xaa.sdf.gz’ saved [235948/235948]
#
# mkdir: created directory 'EE/CARO'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:33--  https://files.docking.org/3D/EE/CARO/EECARO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 98102 (96K) [application/x-gzip]
# Saving to: ‘EE/CARO/EECARO.xaa.sdf.gz’
#
# EE/CARO/EECARO.xaa. 100%[===================>]  95.80K   327KB/s    in 0.3s
#
# 2025-12-18 06:31:33 (327 KB/s) - ‘EE/CARO/EECARO.xaa.sdf.gz’ saved [98102/98102]
#
# mkdir: created directory 'EE/CARP'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:33--  https://files.docking.org/3D/EE/CARP/EECARP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6233 (6.1K) [application/x-gzip]
# Saving to: ‘EE/CARP/EECARP.xaa.sdf.gz’
#
# EE/CARP/EECARP.xaa. 100%[===================>]   6.09K  --.-KB/s    in 0s
#
# 2025-12-18 06:31:33 (2.45 GB/s) - ‘EE/CARP/EECARP.xaa.sdf.gz’ saved [6233/6233]
#
# mkdir: created directory 'EE/CBML'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:33--  https://files.docking.org/3D/EE/CBML/EECBML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4578 (4.5K) [application/x-gzip]
# Saving to: ‘EE/CBML/EECBML.xaa.sdf.gz’
#
# EE/CBML/EECBML.xaa. 100%[===================>]   4.47K  --.-KB/s    in 0s
#
# 2025-12-18 06:31:34 (1.76 GB/s) - ‘EE/CBML/EECBML.xaa.sdf.gz’ saved [4578/4578]
#
# mkdir: created directory 'EE/CBMM'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:34--  https://files.docking.org/3D/EE/CBMM/EECBMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39851 (39K) [application/x-gzip]
# Saving to: ‘EE/CBMM/EECBMM.xaa.sdf.gz’
#
# EE/CBMM/EECBMM.xaa. 100%[===================>]  38.92K  --.-KB/s    in 0.1s
#
# 2025-12-18 06:31:34 (397 KB/s) - ‘EE/CBMM/EECBMM.xaa.sdf.gz’ saved [39851/39851]
#
# mkdir: created directory 'EE/CBMO'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:34--  https://files.docking.org/3D/EE/CBMO/EECBMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38334 (37K) [application/x-gzip]
# Saving to: ‘EE/CBMO/EECBMO.xaa.sdf.gz’
#
# EE/CBMO/EECBMO.xaa. 100%[===================>]  37.44K  --.-KB/s    in 0.1s
#
# 2025-12-18 06:31:34 (382 KB/s) - ‘EE/CBMO/EECBMO.xaa.sdf.gz’ saved [38334/38334]
#
# mkdir: created directory 'EE/CBRL'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:34--  https://files.docking.org/3D/EE/CBRL/EECBRL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6570 (6.4K) [application/x-gzip]
# Saving to: ‘EE/CBRL/EECBRL.xaa.sdf.gz’
#
# EE/CBRL/EECBRL.xaa. 100%[===================>]   6.42K  --.-KB/s    in 0s
#
# 2025-12-18 06:31:35 (2.05 GB/s) - ‘EE/CBRL/EECBRL.xaa.sdf.gz’ saved [6570/6570]
#
# mkdir: created directory 'EE/CBRM'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:35--  https://files.docking.org/3D/EE/CBRM/EECBRM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 105382 (103K) [application/x-gzip]
# Saving to: ‘EE/CBRM/EECBRM.xaa.sdf.gz’
#
# EE/CBRM/EECBRM.xaa. 100%[===================>] 102.91K   351KB/s    in 0.3s
#
# 2025-12-18 06:31:35 (351 KB/s) - ‘EE/CBRM/EECBRM.xaa.sdf.gz’ saved [105382/105382]
#
# mkdir: created directory 'EE/CBRO'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:35--  https://files.docking.org/3D/EE/CBRO/EECBRO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48601 (47K) [application/x-gzip]
# Saving to: ‘EE/CBRO/EECBRO.xaa.sdf.gz’
#
# EE/CBRO/EECBRO.xaa. 100%[===================>]  47.46K  --.-KB/s    in 0.1s
#
# 2025-12-18 06:31:35 (317 KB/s) - ‘EE/CBRO/EECBRO.xaa.sdf.gz’ saved [48601/48601]
#
# mkdir: created directory 'EE/CBRP'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:35--  https://files.docking.org/3D/EE/CBRP/EECBRP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3191 (3.1K) [application/x-gzip]
# Saving to: ‘EE/CBRP/EECBRP.xaa.sdf.gz’
#
# EE/CBRP/EECBRP.xaa. 100%[===================>]   3.12K  --.-KB/s    in 0s
#
# 2025-12-18 06:31:36 (350 MB/s) - ‘EE/CBRP/EECBRP.xaa.sdf.gz’ saved [3191/3191]
#
# mkdir: created directory 'EE/EAML'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:36--  https://files.docking.org/3D/EE/EAML/EEEAML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2421 (2.4K) [application/x-gzip]
# Saving to: ‘EE/EAML/EEEAML.xaa.sdf.gz’
#
# EE/EAML/EEEAML.xaa. 100%[===================>]   2.36K  --.-KB/s    in 0s
#
# 2025-12-18 06:31:36 (1.00 GB/s) - ‘EE/EAML/EEEAML.xaa.sdf.gz’ saved [2421/2421]
#
# mkdir: created directory 'EE/EAMM'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:36--  https://files.docking.org/3D/EE/EAMM/EEEAMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 141044 (138K) [application/x-gzip]
# Saving to: ‘EE/EAMM/EEEAMM.xaa.sdf.gz’
#
# EE/EAMM/EEEAMM.xaa. 100%[===================>] 137.74K   352KB/s    in 0.4s
#
# 2025-12-18 06:31:37 (352 KB/s) - ‘EE/EAMM/EEEAMM.xaa.sdf.gz’ saved [141044/141044]
#
# mkdir: created directory 'EE/EAMO'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:37--  https://files.docking.org/3D/EE/EAMO/EEEAMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 459193 (448K) [application/x-gzip]
# Saving to: ‘EE/EAMO/EEEAMO.xaa.sdf.gz’
#
# EE/EAMO/EEEAMO.xaa. 100%[===================>] 448.43K   482KB/s    in 0.9s
#
# 2025-12-18 06:31:38 (482 KB/s) - ‘EE/EAMO/EEEAMO.xaa.sdf.gz’ saved [459193/459193]
#
# mkdir: created directory 'EE/EAMP'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:38--  https://files.docking.org/3D/EE/EAMP/EEEAMP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25987 (25K) [application/x-gzip]
# Saving to: ‘EE/EAMP/EEEAMP.xaa.sdf.gz’
#
# EE/EAMP/EEEAMP.xaa. 100%[===================>]  25.38K  --.-KB/s    in 0.08s
#
# 2025-12-18 06:31:38 (299 KB/s) - ‘EE/EAMP/EEEAMP.xaa.sdf.gz’ saved [25987/25987]
#
# mkdir: created directory 'EE/EARL'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:38--  https://files.docking.org/3D/EE/EARL/EEEARL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11280 (11K) [application/x-gzip]
# Saving to: ‘EE/EARL/EEEARL.xaa.sdf.gz’
#
# EE/EARL/EEEARL.xaa. 100%[===================>]  11.02K  --.-KB/s    in 0s
#
# 2025-12-18 06:31:38 (107 MB/s) - ‘EE/EARL/EEEARL.xaa.sdf.gz’ saved [11280/11280]
#
# mkdir: created directory 'EE/EARM'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:38--  https://files.docking.org/3D/EE/EARM/EEEARM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 357175 (349K) [application/x-gzip]
# Saving to: ‘EE/EARM/EEEARM.xaa.sdf.gz’
#
# EE/EARM/EEEARM.xaa. 100%[===================>] 348.80K   433KB/s    in 0.8s
#
# 2025-12-18 06:31:39 (433 KB/s) - ‘EE/EARM/EEEARM.xaa.sdf.gz’ saved [357175/357175]
#
# mkdir: created directory 'EE/EARO'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:39--  https://files.docking.org/3D/EE/EARO/EEEARO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 567674 (554K) [application/x-gzip]
# Saving to: ‘EE/EARO/EEEARO.xaa.sdf.gz’
#
# EE/EARO/EEEARO.xaa. 100%[===================>] 554.37K   509KB/s    in 1.1s
#
# 2025-12-18 06:31:41 (509 KB/s) - ‘EE/EARO/EEEARO.xaa.sdf.gz’ saved [567674/567674]
#
# mkdir: created directory 'EE/EARP'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:41--  https://files.docking.org/3D/EE/EARP/EEEARP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19888 (19K) [application/x-gzip]
# Saving to: ‘EE/EARP/EEEARP.xaa.sdf.gz’
#
# EE/EARP/EEEARP.xaa. 100%[===================>]  19.42K  --.-KB/s    in 0.05s
#
# 2025-12-18 06:31:41 (389 KB/s) - ‘EE/EARP/EEEARP.xaa.sdf.gz’ saved [19888/19888]
#
# mkdir: created directory 'EE/EBML'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:41--  https://files.docking.org/3D/EE/EBML/EEEBML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3488 (3.4K) [application/x-gzip]
# Saving to: ‘EE/EBML/EEEBML.xaa.sdf.gz’
#
# EE/EBML/EEEBML.xaa. 100%[===================>]   3.41K  --.-KB/s    in 0s
#
# 2025-12-18 06:31:41 (1.88 GB/s) - ‘EE/EBML/EEEBML.xaa.sdf.gz’ saved [3488/3488]
#
# mkdir: created directory 'EE/EBMM'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:41--  https://files.docking.org/3D/EE/EBMM/EEEBMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 57368 (56K) [application/x-gzip]
# Saving to: ‘EE/EBMM/EEEBMM.xaa.sdf.gz’
#
# EE/EBMM/EEEBMM.xaa. 100%[===================>]  56.02K  --.-KB/s    in 0.1s
#
# 2025-12-18 06:31:42 (374 KB/s) - ‘EE/EBMM/EEEBMM.xaa.sdf.gz’ saved [57368/57368]
#
# mkdir: created directory 'EE/EBMO'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:42--  https://files.docking.org/3D/EE/EBMO/EEEBMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 257775 (252K) [application/x-gzip]
# Saving to: ‘EE/EBMO/EEEBMO.xaa.sdf.gz’
#
# EE/EBMO/EEEBMO.xaa. 100%[===================>] 251.73K   421KB/s    in 0.6s
#
# 2025-12-18 06:31:43 (421 KB/s) - ‘EE/EBMO/EEEBMO.xaa.sdf.gz’ saved [257775/257775]
#
# mkdir: created directory 'EE/EBMP'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:43--  https://files.docking.org/3D/EE/EBMP/EEEBMP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8757 (8.6K) [application/x-gzip]
# Saving to: ‘EE/EBMP/EEEBMP.xaa.sdf.gz’
#
# EE/EBMP/EEEBMP.xaa. 100%[===================>]   8.55K  --.-KB/s    in 0s
#
# 2025-12-18 06:31:43 (132 MB/s) - ‘EE/EBMP/EEEBMP.xaa.sdf.gz’ saved [8757/8757]
#
# mkdir: created directory 'EE/EBRL'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:43--  https://files.docking.org/3D/EE/EBRL/EEEBRL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6927 (6.8K) [application/x-gzip]
# Saving to: ‘EE/EBRL/EEEBRL.xaa.sdf.gz’
#
# EE/EBRL/EEEBRL.xaa. 100%[===================>]   6.76K  --.-KB/s    in 0s
#
# 2025-12-18 06:31:43 (2.09 GB/s) - ‘EE/EBRL/EEEBRL.xaa.sdf.gz’ saved [6927/6927]
#
# mkdir: created directory 'EE/EBRM'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:43--  https://files.docking.org/3D/EE/EBRM/EEEBRM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 255042 (249K) [application/x-gzip]
# Saving to: ‘EE/EBRM/EEEBRM.xaa.sdf.gz’
#
# EE/EBRM/EEEBRM.xaa. 100%[===================>] 249.06K   392KB/s    in 0.6s
#
# 2025-12-18 06:31:44 (392 KB/s) - ‘EE/EBRM/EEEBRM.xaa.sdf.gz’ saved [255042/255042]
#
# mkdir: created directory 'EE/EBRO'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:44--  https://files.docking.org/3D/EE/EBRO/EEEBRO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 362796 (354K) [application/x-gzip]
# Saving to: ‘EE/EBRO/EEEBRO.xaa.sdf.gz’
#
# EE/EBRO/EEEBRO.xaa. 100%[===================>] 354.29K   417KB/s    in 0.8s
#
# 2025-12-18 06:31:45 (417 KB/s) - ‘EE/EBRO/EEEBRO.xaa.sdf.gz’ saved [362796/362796]
#
# mkdir: created directory 'EE/EBRP'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:45--  https://files.docking.org/3D/EE/EBRP/EEEBRP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15819 (15K) [application/x-gzip]
# Saving to: ‘EE/EBRP/EEEBRP.xaa.sdf.gz’
#
# EE/EBRP/EEEBRP.xaa. 100%[===================>]  15.45K  --.-KB/s    in 0.05s
#
# 2025-12-18 06:31:45 (338 KB/s) - ‘EE/EBRP/EEEBRP.xaa.sdf.gz’ saved [15819/15819]
#
# mkdir: created directory 'CF/CBMO'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:45--  https://files.docking.org/3D/CF/CBMO/CFCBMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24325 (24K) [application/x-gzip]
# Saving to: ‘CF/CBMO/CFCBMO.xaa.sdf.gz’
#
# CF/CBMO/CFCBMO.xaa. 100%[===================>]  23.75K  --.-KB/s    in 0.05s
#
# 2025-12-18 06:31:46 (497 KB/s) - ‘CF/CBMO/CFCBMO.xaa.sdf.gz’ saved [24325/24325]
#
# mkdir: created directory 'CF/CBMP'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:46--  https://files.docking.org/3D/CF/CBMP/CFCBMP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1693 (1.7K) [application/x-gzip]
# Saving to: ‘CF/CBMP/CFCBMP.xaa.sdf.gz’
#
# CF/CBMP/CFCBMP.xaa. 100%[===================>]   1.65K  --.-KB/s    in 0s
#
# 2025-12-18 06:31:46 (848 MB/s) - ‘CF/CBMP/CFCBMP.xaa.sdf.gz’ saved [1693/1693]
#
# mkdir: created directory 'CF/CBRL'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:46--  https://files.docking.org/3D/CF/CBRL/CFCBRL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1140 (1.1K) [application/x-gzip]
# Saving to: ‘CF/CBRL/CFCBRL.xaa.sdf.gz’
#
# CF/CBRL/CFCBRL.xaa. 100%[===================>]   1.11K  --.-KB/s    in 0s
#
# 2025-12-18 06:31:46 (704 MB/s) - ‘CF/CBRL/CFCBRL.xaa.sdf.gz’ saved [1140/1140]
#
# mkdir: created directory 'CF/CBRM'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:46--  https://files.docking.org/3D/CF/CBRM/CFCBRM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 32455 (32K) [application/x-gzip]
# Saving to: ‘CF/CBRM/CFCBRM.xaa.sdf.gz’
#
# CF/CBRM/CFCBRM.xaa. 100%[===================>]  31.69K   148KB/s    in 0.2s
#
# 2025-12-18 06:31:46 (148 KB/s) - ‘CF/CBRM/CFCBRM.xaa.sdf.gz’ saved [32455/32455]
#
# mkdir: created directory 'CF/CBRO'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:46--  https://files.docking.org/3D/CF/CBRO/CFCBRO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 53275 (52K) [application/x-gzip]
# Saving to: ‘CF/CBRO/CFCBRO.xaa.sdf.gz’
#
# CF/CBRO/CFCBRO.xaa. 100%[===================>]  52.03K  --.-KB/s    in 0.1s
#
# 2025-12-18 06:31:47 (359 KB/s) - ‘CF/CBRO/CFCBRO.xaa.sdf.gz’ saved [53275/53275]
#
# mkdir: created directory 'CF/CBRP'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:47--  https://files.docking.org/3D/CF/CBRP/CFCBRP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3243 (3.2K) [application/x-gzip]
# Saving to: ‘CF/CBRP/CFCBRP.xaa.sdf.gz’
#
# CF/CBRP/CFCBRP.xaa. 100%[===================>]   3.17K  --.-KB/s    in 0s
#
# 2025-12-18 06:31:47 (1.52 GB/s) - ‘CF/CBRP/CFCBRP.xaa.sdf.gz’ saved [3243/3243]
#
# mkdir: created directory 'CF/EAML'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:47--  https://files.docking.org/3D/CF/EAML/CFEAML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3666 (3.6K) [application/x-gzip]
# Saving to: ‘CF/EAML/CFEAML.xaa.sdf.gz’
#
# CF/EAML/CFEAML.xaa. 100%[===================>]   3.58K  --.-KB/s    in 0s
#
# 2025-12-18 06:31:47 (1.84 GB/s) - ‘CF/EAML/CFEAML.xaa.sdf.gz’ saved [3666/3666]
#
# mkdir: created directory 'CF/EAMM'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:47--  https://files.docking.org/3D/CF/EAMM/CFEAMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 175232 (171K) [application/x-gzip]
# Saving to: ‘CF/EAMM/CFEAMM.xaa.sdf.gz’
#
# CF/EAMM/CFEAMM.xaa. 100%[===================>] 171.12K   348KB/s    in 0.5s
#
# 2025-12-18 06:31:48 (348 KB/s) - ‘CF/EAMM/CFEAMM.xaa.sdf.gz’ saved [175232/175232]
#
# mkdir: created directory 'CF/EAMO'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:48--  https://files.docking.org/3D/CF/EAMO/CFEAMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 801782 (783K) [application/x-gzip]
# Saving to: ‘CF/EAMO/CFEAMO.xaa.sdf.gz’
#
# CF/EAMO/CFEAMO.xaa. 100%[===================>] 782.99K   585KB/s    in 1.3s
#
# 2025-12-18 06:31:50 (585 KB/s) - ‘CF/EAMO/CFEAMO.xaa.sdf.gz’ saved [801782/801782]
#
# mkdir: created directory 'CF/EAMP'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:50--  https://files.docking.org/3D/CF/EAMP/CFEAMP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 52535 (51K) [application/x-gzip]
# Saving to: ‘CF/EAMP/CFEAMP.xaa.sdf.gz’
#
# CF/EAMP/CFEAMP.xaa. 100%[===================>]  51.30K   337KB/s    in 0.2s
#
# 2025-12-18 06:31:50 (337 KB/s) - ‘CF/EAMP/CFEAMP.xaa.sdf.gz’ saved [52535/52535]
#
# mkdir: created directory 'CF/EARL'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:50--  https://files.docking.org/3D/CF/EARL/CFEARL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6109 (6.0K) [application/x-gzip]
# Saving to: ‘CF/EARL/CFEARL.xaa.sdf.gz’
#
# CF/EARL/CFEARL.xaa. 100%[===================>]   5.97K  --.-KB/s    in 0s
#
# 2025-12-18 06:31:50 (2.01 GB/s) - ‘CF/EARL/CFEARL.xaa.sdf.gz’ saved [6109/6109]
#
# mkdir: created directory 'CF/EARM'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:50--  https://files.docking.org/3D/CF/EARM/CFEARM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 530962 (519K) [application/x-gzip]
# Saving to: ‘CF/EARM/CFEARM.xaa.sdf.gz’
#
# CF/EARM/CFEARM.xaa. 100%[===================>] 518.52K   520KB/s    in 1.0s
#
# 2025-12-18 06:31:51 (520 KB/s) - ‘CF/EARM/CFEARM.xaa.sdf.gz’ saved [530962/530962]
#
# mkdir: created directory 'CF/EARO'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:52--  https://files.docking.org/3D/CF/EARO/CFEARO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1353954 (1.3M) [application/x-gzip]
# Saving to: ‘CF/EARO/CFEARO.xaa.sdf.gz’
#
# CF/EARO/CFEARO.xaa. 100%[===================>]   1.29M   492KB/s    in 2.7s
#
# 2025-12-18 06:31:54 (492 KB/s) - ‘CF/EARO/CFEARO.xaa.sdf.gz’ saved [1353954/1353954]
#
# mkdir: created directory 'CF/EARP'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:54--  https://files.docking.org/3D/CF/EARP/CFEARP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26569 (26K) [application/x-gzip]
# Saving to: ‘CF/EARP/CFEARP.xaa.sdf.gz’
#
# CF/EARP/CFEARP.xaa. 100%[===================>]  25.95K  --.-KB/s    in 0.09s
#
# 2025-12-18 06:31:55 (299 KB/s) - ‘CF/EARP/CFEARP.xaa.sdf.gz’ saved [26569/26569]
#
# mkdir: created directory 'CF/EBML'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:55--  https://files.docking.org/3D/CF/EBML/CFEBML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1769 (1.7K) [application/x-gzip]
# Saving to: ‘CF/EBML/CFEBML.xaa.sdf.gz’
#
# CF/EBML/CFEBML.xaa. 100%[===================>]   1.73K  --.-KB/s    in 0s
#
# 2025-12-18 06:31:55 (785 MB/s) - ‘CF/EBML/CFEBML.xaa.sdf.gz’ saved [1769/1769]
#
# mkdir: created directory 'CF/EBMM'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:55--  https://files.docking.org/3D/CF/EBMM/CFEBMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 56704 (55K) [application/x-gzip]
# Saving to: ‘CF/EBMM/CFEBMM.xaa.sdf.gz’
#
# CF/EBMM/CFEBMM.xaa. 100%[===================>]  55.38K  --.-KB/s    in 0.1s
#
# 2025-12-18 06:31:55 (372 KB/s) - ‘CF/EBMM/CFEBMM.xaa.sdf.gz’ saved [56704/56704]
#
# mkdir: created directory 'CF/EBMO'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:55--  https://files.docking.org/3D/CF/EBMO/CFEBMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 148674 (145K) [application/x-gzip]
# Saving to: ‘CF/EBMO/CFEBMO.xaa.sdf.gz’
#
# CF/EBMO/CFEBMO.xaa. 100%[===================>] 145.19K   359KB/s    in 0.4s
#
# 2025-12-18 06:31:56 (359 KB/s) - ‘CF/EBMO/CFEBMO.xaa.sdf.gz’ saved [148674/148674]
#
# mkdir: created directory 'CF/EBMP'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:56--  https://files.docking.org/3D/CF/EBMP/CFEBMP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2158 (2.1K) [application/x-gzip]
# Saving to: ‘CF/EBMP/CFEBMP.xaa.sdf.gz’
#
# CF/EBMP/CFEBMP.xaa. 100%[===================>]   2.11K  --.-KB/s    in 0s
#
# 2025-12-18 06:31:56 (872 MB/s) - ‘CF/EBMP/CFEBMP.xaa.sdf.gz’ saved [2158/2158]
#
# mkdir: created directory 'CF/EBRL'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:56--  https://files.docking.org/3D/CF/EBRL/CFEBRL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8492 (8.3K) [application/x-gzip]
# Saving to: ‘CF/EBRL/CFEBRL.xaa.sdf.gz’
#
# CF/EBRL/CFEBRL.xaa. 100%[===================>]   8.29K  --.-KB/s    in 0s
#
# 2025-12-18 06:31:56 (111 MB/s) - ‘CF/EBRL/CFEBRL.xaa.sdf.gz’ saved [8492/8492]
#
# mkdir: created directory 'CF/EBRM'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:56--  https://files.docking.org/3D/CF/EBRM/CFEBRM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 174431 (170K) [application/x-gzip]
# Saving to: ‘CF/EBRM/CFEBRM.xaa.sdf.gz’
#
# CF/EBRM/CFEBRM.xaa. 100%[===================>] 170.34K   363KB/s    in 0.5s
#
# 2025-12-18 06:31:57 (363 KB/s) - ‘CF/EBRM/CFEBRM.xaa.sdf.gz’ saved [174431/174431]
#
# mkdir: created directory 'CF/EBRO'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:57--  https://files.docking.org/3D/CF/EBRO/CFEBRO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 231981 (227K) [application/x-gzip]
# Saving to: ‘CF/EBRO/CFEBRO.xaa.sdf.gz’
#
# CF/EBRO/CFEBRO.xaa. 100%[===================>] 226.54K   385KB/s    in 0.6s
#
# 2025-12-18 06:31:58 (385 KB/s) - ‘CF/EBRO/CFEBRO.xaa.sdf.gz’ saved [231981/231981]
#
# mkdir: created directory 'CF/EBRP'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:58--  https://files.docking.org/3D/CF/EBRP/CFEBRP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17064 (17K) [application/x-gzip]
# Saving to: ‘CF/EBRP/CFEBRP.xaa.sdf.gz’
#
# CF/EBRP/CFEBRP.xaa. 100%[===================>]  16.66K  --.-KB/s    in 0.04s
#
# 2025-12-18 06:31:58 (381 KB/s) - ‘CF/EBRP/CFEBRP.xaa.sdf.gz’ saved [17064/17064]
#
# mkdir: created directory 'DF'
# mkdir: created directory 'DF/AAML'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:58--  https://files.docking.org/3D/DF/AAML/DFAAML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58656 (57K) [application/x-gzip]
# Saving to: ‘DF/AAML/DFAAML.xaa.sdf.gz’
#
# DF/AAML/DFAAML.xaa. 100%[===================>]  57.28K   380KB/s    in 0.2s
#
# 2025-12-18 06:31:59 (380 KB/s) - ‘DF/AAML/DFAAML.xaa.sdf.gz’ saved [58656/58656]
#
# mkdir: created directory 'DF/AAMM'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:31:59--  https://files.docking.org/3D/DF/AAMM/DFAAMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 748424 (731K) [application/x-gzip]
# Saving to: ‘DF/AAMM/DFAAMM.xaa.sdf.gz’
#
# DF/AAMM/DFAAMM.xaa. 100%[===================>] 730.88K   545KB/s    in 1.3s
#
# 2025-12-18 06:32:01 (545 KB/s) - ‘DF/AAMM/DFAAMM.xaa.sdf.gz’ saved [748424/748424]
#
# mkdir: created directory 'DF/AAMO'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:32:01--  https://files.docking.org/3D/DF/AAMO/DFAAMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6205483 (5.9M) [application/x-gzip]
# Saving to: ‘DF/AAMO/DFAAMO.xaa.sdf.gz’
#
# DF/AAMO/DFAAMO.xaa. 100%[===================>]   5.92M  1.78MB/s    in 3.3s
#
# 2025-12-18 06:32:04 (1.78 MB/s) - ‘DF/AAMO/DFAAMO.xaa.sdf.gz’ saved [6205483/6205483]
#
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:32:04--  https://files.docking.org/3D/DF/AAMO/DFAAMO.xab.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3853524 (3.7M) [application/x-gzip]
# Saving to: ‘DF/AAMO/DFAAMO.xab.sdf.gz’
#
# DF/AAMO/DFAAMO.xab. 100%[===================>]   3.67M  1.18MB/s    in 3.1s
#
# 2025-12-18 06:32:07 (1.18 MB/s) - ‘DF/AAMO/DFAAMO.xab.sdf.gz’ saved [3853524/3853524]
#
# mkdir: created directory 'DF/AAMP'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:32:07--  https://files.docking.org/3D/DF/AAMP/DFAAMP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 769415 (751K) [application/x-gzip]
# Saving to: ‘DF/AAMP/DFAAMP.xaa.sdf.gz’
#
# DF/AAMP/DFAAMP.xaa. 100%[===================>] 751.38K   605KB/s    in 1.2s
#
# 2025-12-18 06:32:09 (605 KB/s) - ‘DF/AAMP/DFAAMP.xaa.sdf.gz’ saved [769415/769415]
#
# mkdir: created directory 'DF/AARL'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:32:09--  https://files.docking.org/3D/DF/AARL/DFAARL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 103728 (101K) [application/x-gzip]
# Saving to: ‘DF/AARL/DFAARL.xaa.sdf.gz’
#
# DF/AARL/DFAARL.xaa. 100%[===================>] 101.30K   341KB/s    in 0.3s
#
# 2025-12-18 06:32:10 (341 KB/s) - ‘DF/AARL/DFAARL.xaa.sdf.gz’ saved [103728/103728]
#
# mkdir: created directory 'DF/AARM'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:32:10--  https://files.docking.org/3D/DF/AARM/DFAARM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4635792 (4.4M) [application/x-gzip]
# Saving to: ‘DF/AARM/DFAARM.xaa.sdf.gz’
#
# DF/AARM/DFAARM.xaa. 100%[===================>]   4.42M  1.19MB/s    in 4.3s
#
# 2025-12-18 06:32:14 (1.04 MB/s) - ‘DF/AARM/DFAARM.xaa.sdf.gz’ saved [4635792/4635792]
#
# mkdir: created directory 'DF/AARO'
# URL transformed to HTTPS due to an HSTS policy
# ...
# --2025-12-18 06:36:07--  https://files.docking.org/3D/EG/CARM/EGCARM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 244502 (239K) [application/x-gzip]
# Saving to: ‘EG/CARM/EGCARM.xaa.sdf.gz’
#
# EG/CARM/EGCARM.xaa. 100%[===================>] 238.77K   368KB/s    in 0.6s
#
# 2025-12-18 06:36:08 (368 KB/s) - ‘EG/CARM/EGCARM.xaa.sdf.gz’ saved [244502/244502]
#
# mkdir: created directory 'EG/CARO'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:36:08--  https://files.docking.org/3D/EG/CARO/EGCARO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 168183 (164K) [application/x-gzip]
# Saving to: ‘EG/CARO/EGCARO.xaa.sdf.gz’
#
# EG/CARO/EGCARO.xaa. 100%[===================>] 164.24K   369KB/s    in 0.4s
#
# 2025-12-18 06:36:09 (369 KB/s) - ‘EG/CARO/EGCARO.xaa.sdf.gz’ saved [168183/168183]
#
# mkdir: created directory 'EG/CARP'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:36:09--  https://files.docking.org/3D/EG/CARP/EGCARP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2794 (2.7K) [application/x-gzip]
# Saving to: ‘EG/CARP/EGCARP.xaa.sdf.gz’
#
# EG/CARP/EGCARP.xaa. 100%[===================>]   2.73K  --.-KB/s    in 0s
#
# 2025-12-18 06:36:09 (1.10 GB/s) - ‘EG/CARP/EGCARP.xaa.sdf.gz’ saved [2794/2794]
#
# mkdir: created directory 'EG/CBML'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:36:09--  https://files.docking.org/3D/EG/CBML/EGCBML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4201 (4.1K) [application/x-gzip]
# Saving to: ‘EG/CBML/EGCBML.xaa.sdf.gz’
#
# EG/CBML/EGCBML.xaa. 100%[===================>]   4.10K  --.-KB/s    in 0s
#
# 2025-12-18 06:36:10 (1.60 GB/s) - ‘EG/CBML/EGCBML.xaa.sdf.gz’ saved [4201/4201]
#
# mkdir: created directory 'EG/CBMM'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:36:10--  https://files.docking.org/3D/EG/CBMM/EGCBMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40249 (39K) [application/x-gzip]
# Saving to: ‘EG/CBMM/EGCBMM.xaa.sdf.gz’
#
# EG/CBMM/EGCBMM.xaa. 100%[===================>]  39.31K  --.-KB/s    in 0.1s
#
# 2025-12-18 06:36:10 (397 KB/s) - ‘EG/CBMM/EGCBMM.xaa.sdf.gz’ saved [40249/40249]
#
# mkdir: created directory 'EG/CBMO'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:36:10--  https://files.docking.org/3D/EG/CBMO/EGCBMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42541 (42K) [application/x-gzip]
# Saving to: ‘EG/CBMO/EGCBMO.xaa.sdf.gz’
#
# EG/CBMO/EGCBMO.xaa. 100%[===================>]  41.54K  --.-KB/s    in 0.1s
#
# 2025-12-18 06:36:10 (429 KB/s) - ‘EG/CBMO/EGCBMO.xaa.sdf.gz’ saved [42541/42541]
#
# mkdir: created directory 'EG/CBMP'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:36:10--  https://files.docking.org/3D/EG/CBMP/EGCBMP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4254 (4.2K) [application/x-gzip]
# Saving to: ‘EG/CBMP/EGCBMP.xaa.sdf.gz’
#
# EG/CBMP/EGCBMP.xaa. 100%[===================>]   4.15K  --.-KB/s    in 0s
#
# 2025-12-18 06:36:11 (1.59 GB/s) - ‘EG/CBMP/EGCBMP.xaa.sdf.gz’ saved [4254/4254]
#
# mkdir: created directory 'EG/CBRL'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:36:11--  https://files.docking.org/3D/EG/CBRL/EGCBRL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2162 (2.1K) [application/x-gzip]
# Saving to: ‘EG/CBRL/EGCBRL.xaa.sdf.gz’
#
# EG/CBRL/EGCBRL.xaa. 100%[===================>]   2.11K  --.-KB/s    in 0s
#
# 2025-12-18 06:36:11 (884 MB/s) - ‘EG/CBRL/EGCBRL.xaa.sdf.gz’ saved [2162/2162]
#
# mkdir: created directory 'EG/CBRM'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:36:11--  https://files.docking.org/3D/EG/CBRM/EGCBRM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 147083 (144K) [application/x-gzip]
# Saving to: ‘EG/CBRM/EGCBRM.xaa.sdf.gz’
#
# EG/CBRM/EGCBRM.xaa. 100%[===================>] 143.64K   364KB/s    in 0.4s
#
# 2025-12-18 06:36:12 (364 KB/s) - ‘EG/CBRM/EGCBRM.xaa.sdf.gz’ saved [147083/147083]
#
# mkdir: created directory 'EG/CBRO'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:36:12--  https://files.docking.org/3D/EG/CBRO/EGCBRO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 77654 (76K) [application/x-gzip]
# Saving to: ‘EG/CBRO/EGCBRO.xaa.sdf.gz’
#
# EG/CBRO/EGCBRO.xaa. 100%[===================>]  75.83K   307KB/s    in 0.2s
#
# 2025-12-18 06:36:12 (307 KB/s) - ‘EG/CBRO/EGCBRO.xaa.sdf.gz’ saved [77654/77654]
#
# mkdir: created directory 'EG/CBRP'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:36:12--  https://files.docking.org/3D/EG/CBRP/EGCBRP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6582 (6.4K) [application/x-gzip]
# Saving to: ‘EG/CBRP/EGCBRP.xaa.sdf.gz’
#
# EG/CBRP/EGCBRP.xaa. 100%[===================>]   6.43K  --.-KB/s    in 0s
#
# 2025-12-18 06:36:12 (2.85 GB/s) - ‘EG/CBRP/EGCBRP.xaa.sdf.gz’ saved [6582/6582]
#
# mkdir: created directory 'EG/EAML'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:36:12--  https://files.docking.org/3D/EG/EAML/EGEAML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-12-18 06:36:13 ERROR 404: Not Found.
#
# mkdir: created directory 'EG/EAMM'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:36:13--  https://files.docking.org/3D/EG/EAMM/EGEAMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89884 (88K) [application/x-gzip]
# Saving to: ‘EG/EAMM/EGEAMM.xaa.sdf.gz’
#
# EG/EAMM/EGEAMM.xaa. 100%[===================>]  87.78K   353KB/s    in 0.2s
#
# 2025-12-18 06:36:13 (353 KB/s) - ‘EG/EAMM/EGEAMM.xaa.sdf.gz’ saved [89884/89884]
#
# mkdir: created directory 'EG/EAMO'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:36:13--  https://files.docking.org/3D/EG/EAMO/EGEAMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 339953 (332K) [application/x-gzip]
# Saving to: ‘EG/EAMO/EGEAMO.xaa.sdf.gz’
#
# EG/EAMO/EGEAMO.xaa. 100%[===================>] 331.99K   445KB/s    in 0.7s
#
# 2025-12-18 06:36:14 (445 KB/s) - ‘EG/EAMO/EGEAMO.xaa.sdf.gz’ saved [339953/339953]
#
# mkdir: created directory 'EG/EAMP'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:36:14--  https://files.docking.org/3D/EG/EAMP/EGEAMP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21723 (21K) [application/x-gzip]
# Saving to: ‘EG/EAMP/EGEAMP.xaa.sdf.gz’
#
# EG/EAMP/EGEAMP.xaa. 100%[===================>]  21.21K  --.-KB/s    in 0.05s
#
# 2025-12-18 06:36:15 (436 KB/s) - ‘EG/EAMP/EGEAMP.xaa.sdf.gz’ saved [21723/21723]
#
# mkdir: created directory 'EG/EARL'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:36:15--  https://files.docking.org/3D/EG/EARL/EGEARL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8159 (8.0K) [application/x-gzip]
# Saving to: ‘EG/EARL/EGEARL.xaa.sdf.gz’
#
# EG/EARL/EGEARL.xaa. 100%[===================>]   7.97K  --.-KB/s    in 0s
#
# 2025-12-18 06:36:15 (129 MB/s) - ‘EG/EARL/EGEARL.xaa.sdf.gz’ saved [8159/8159]
#
# mkdir: created directory 'EG/EARM'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:36:15--  https://files.docking.org/3D/EG/EARM/EGEARM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 245865 (240K) [application/x-gzip]
# Saving to: ‘EG/EARM/EGEARM.xaa.sdf.gz’
#
# EG/EARM/EGEARM.xaa. 100%[===================>] 240.10K   405KB/s    in 0.6s
#
# 2025-12-18 06:36:16 (405 KB/s) - ‘EG/EARM/EGEARM.xaa.sdf.gz’ saved [245865/245865]
#
# mkdir: created directory 'EG/EARO'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:36:16--  https://files.docking.org/3D/EG/EARO/EGEARO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 529909 (517K) [application/x-gzip]
# Saving to: ‘EG/EARO/EGEARO.xaa.sdf.gz’
#
# EG/EARO/EGEARO.xaa. 100%[===================>] 517.49K   517KB/s    in 1.0s
#
# 2025-12-18 06:36:17 (517 KB/s) - ‘EG/EARO/EGEARO.xaa.sdf.gz’ saved [529909/529909]
#
# mkdir: created directory 'EG/EARP'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:36:17--  https://files.docking.org/3D/EG/EARP/EGEARP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12567 (12K) [application/x-gzip]
# Saving to: ‘EG/EARP/EGEARP.xaa.sdf.gz’
#
# EG/EARP/EGEARP.xaa. 100%[===================>]  12.27K  --.-KB/s    in 0.02s
#
# 2025-12-18 06:36:17 (795 KB/s) - ‘EG/EARP/EGEARP.xaa.sdf.gz’ saved [12567/12567]
#
# mkdir: created directory 'EG/EBML'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:36:17--  https://files.docking.org/3D/EG/EBML/EGEBML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 691 [application/x-gzip]
# Saving to: ‘EG/EBML/EGEBML.xaa.sdf.gz’
#
# EG/EBML/EGEBML.xaa. 100%[===================>]     691  --.-KB/s    in 0s
#
# 2025-12-18 06:36:18 (355 MB/s) - ‘EG/EBML/EGEBML.xaa.sdf.gz’ saved [691/691]
#
# mkdir: created directory 'EG/EBMM'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:36:18--  https://files.docking.org/3D/EG/EBMM/EGEBMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68530 (67K) [application/x-gzip]
# Saving to: ‘EG/EBMM/EGEBMM.xaa.sdf.gz’
#
# EG/EBMM/EGEBMM.xaa. 100%[===================>]  66.92K   338KB/s    in 0.2s
#
# 2025-12-18 06:36:18 (338 KB/s) - ‘EG/EBMM/EGEBMM.xaa.sdf.gz’ saved [68530/68530]
#
# mkdir: created directory 'EG/EBMO'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:36:18--  https://files.docking.org/3D/EG/EBMO/EGEBMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 218741 (214K) [application/x-gzip]
# Saving to: ‘EG/EBMO/EGEBMO.xaa.sdf.gz’
#
# EG/EBMO/EGEBMO.xaa. 100%[===================>] 213.61K   393KB/s    in 0.5s
#
# 2025-12-18 06:36:19 (393 KB/s) - ‘EG/EBMO/EGEBMO.xaa.sdf.gz’ saved [218741/218741]
#
# mkdir: created directory 'EG/EBMP'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:36:19--  https://files.docking.org/3D/EG/EBMP/EGEBMP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6413 (6.3K) [application/x-gzip]
# Saving to: ‘EG/EBMP/EGEBMP.xaa.sdf.gz’
#
# EG/EBMP/EGEBMP.xaa. 100%[===================>]   6.26K  --.-KB/s    in 0s
#
# 2025-12-18 06:36:19 (2.65 GB/s) - ‘EG/EBMP/EGEBMP.xaa.sdf.gz’ saved [6413/6413]
#
# mkdir: created directory 'EG/EBRL'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:36:19--  https://files.docking.org/3D/EG/EBRL/EGEBRL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12408 (12K) [application/x-gzip]
# Saving to: ‘EG/EBRL/EGEBRL.xaa.sdf.gz’
#
# EG/EBRL/EGEBRL.xaa. 100%[===================>]  12.12K  --.-KB/s    in 0s
#
# 2025-12-18 06:36:19 (101 MB/s) - ‘EG/EBRL/EGEBRL.xaa.sdf.gz’ saved [12408/12408]
#
# mkdir: created directory 'EG/EBRM'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:36:19--  https://files.docking.org/3D/EG/EBRM/EGEBRM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 338855 (331K) [application/x-gzip]
# Saving to: ‘EG/EBRM/EGEBRM.xaa.sdf.gz’
#
# EG/EBRM/EGEBRM.xaa. 100%[===================>] 330.91K   434KB/s    in 0.8s
#
# 2025-12-18 06:36:21 (434 KB/s) - ‘EG/EBRM/EGEBRM.xaa.sdf.gz’ saved [338855/338855]
#
# mkdir: created directory 'EG/EBRO'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:36:21--  https://files.docking.org/3D/EG/EBRO/EGEBRO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 327684 (320K) [application/x-gzip]
# Saving to: ‘EG/EBRO/EGEBRO.xaa.sdf.gz’
#
# EG/EBRO/EGEBRO.xaa. 100%[===================>] 320.00K   433KB/s    in 0.7s
#
# 2025-12-18 06:36:22 (433 KB/s) - ‘EG/EBRO/EGEBRO.xaa.sdf.gz’ saved [327684/327684]
#
# mkdir: created directory 'EG/EBRP'
# URL transformed to HTTPS due to an HSTS policy
# --2025-12-18 06:36:22--  https://files.docking.org/3D/EG/EBRP/EGEBRP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6649 (6.5K) [application/x-gzip]
# Saving to: ‘EG/EBRP/EGEBRP.xaa.sdf.gz’
#
# EG/EBRP/EGEBRP.xaa. 100%[===================>]   6.49K  --.-KB/s    in 0s
#
# 2025-12-18 06:36:22 (2.03 GB/s) - ‘EG/EBRP/EGEBRP.xaa.sdf.gz’ saved [6649/6649]

# %% [markdown]
# # Processing after download

# %%
#@title Write a bash for processing
com_file = open('1.sh','w')
com_file.write('''
#!/bin/bash

# 进入每个子文件夹
for dir in */; do
  cd "$dir"
  # 进入内部文件夹
  for inner_dir in */; do
    cd "$inner_dir"
    # 解压所有.gz文件
    for file in *.gz; do
      gunzip "$file"
    done
    # 复制所有解压后的文件到上层文件夹
    mv *.sdf ../../
    cd ../
  done
  cd ../
done

# 合并所有文件
cat *.sdf > all_zinc.sdf
''')
com_file.close()

# %%
#@title Run bash
# !sh 1.sh
# Out:
# gzip: CBAAML.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CBAAMM.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CBAAMO.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CBAAMP.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CCAAMP.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CCAARL.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CCAARM.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CCAARO.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CCAARP.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CCABML.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CCABMM.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CCABMO.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CCABMP.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CCABRM.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CECBRL.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: DCAAMO.xab.sdf.gz: unexpected end of file
#
# gzip: DCAARO.xab.sdf.gz: unexpected end of file
#
# gzip: DEEBRL.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: EAABMM.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: EBEBRP.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: EFBAMP.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: EGBAMP.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: EGEAML.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
# 1.sh: 9: cd: can't cd to */
# gzip: *.gz: No such file or directory
# mv: cannot stat '*.sdf': No such file or directory
# cat: all_zinc.sdf: input file is output file
